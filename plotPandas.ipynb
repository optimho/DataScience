# %%
import pandas as pd
import numpy as np

# %%
ser1 = pd.Series(np.random.randn(10).cumsum())
ser1
# Out:
# 0   -0.061821
# 1   -0.488715
# 2    0.067182
# 3    0.923556
# 4    1.382345
# 5    2.109038
# 6    1.727817
# 7    1.508777
# 8    2.365360
# 9    1.601836
# dtype: float64

# %%
ser1.plot()
# Out:
# <AxesSubplot:>

# %%
data1 = pd.read_csv('data/ex7.csv', index_col='year')
data1
# Out:
#       sale1  sale2  sale3
# year
# 2010    100    258    592
# 2011    128    364    606
# 2012    156    249    732
# 2013    109    271    629
# 2014    248    363    929
# 2015    375    299    610
# 2016    145    356    540
# 2017     90    212    673
# 2018     29    336    432
# 2019     69    277    421
# 2020    265    368    862
# 2021    184    292    688

# %%
data1.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
data1.plot(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
data1.plot(subplots=True, layout=(1,3))
# Out:
# array([[<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#         <AxesSubplot:xlabel='year'>]], dtype=object)

# %%
data1.plot(subplots=True, figsize=(12,6))
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
data1.plot(subplots=True, figsize=(12,6), legend=False, title='Company Sales Data')
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
data1.plot(subplots=True, layout=(1,3), sharey=True, title="Company data")
# Out:
# array([[<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#         <AxesSubplot:xlabel='year'>]], dtype=object)

# %%
data1.sale1.plot()
# Out:
# <AxesSubplot:xlabel='year'>
