# %% [markdown]
# ![title](img/cover4.png)

# %% [markdown]
# <center><em>Copyright! This material is protected, please do not copy or distribute.    by:Taher Assaf</em></center>

# %% [markdown]
# ***
# <h1 align="center">Udemy course : Python Bootcamp for Data Science 2021 Numpy Pandas & Seaborn</h1>
#
# ***

# %% [markdown]
# ### The Exercises for  Module 13
#
# #### Instruction:  Please write your code after the phrase " ## Your codes begin here:"

# %% [markdown]
# #### Q1. Create line plots for the four arrays (which are created in the first code cell below) in four separate subplots?
#
# **Hint1:** Do not forget to run the first code cell below to create the arrays for you.
#
# **Hint2:** You will need to create four subplots using the function **plt.subplots()**.
#
# **Hint3:** Refer to the second lecture of module 13 for more information.

# %%
## just run this cell to create the four arrays

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(50)   ## Used to generate the same numbers each time we run the script.


array1 = np.random.randn(10).cumsum()
array2 = np.random.randn(10).cumsum()
array3 = np.random.randn(10).cumsum()
array4 = np.random.randn(10).cumsum()

# %%
## Your codes begin here:

fig = plt.figure(figsize=(8,6))
aux1 = fig.add_subplot(2,2,1)
aux2 = fig.add_subplot(2,2,2)
aux3 = fig.add_subplot(2,2,3)
aux4 = fig.add_subplot(2,2,4)
aux1.plot(array1)
aux2.plot(array2)
aux3.plot(array3)
aux4.plot(array4)

# %% [markdown]
# #### Q2. Modify your answer code in Q1, to change the color of the plots into (green, blue, red and black), respectively? And to add circle-markers to all plots?

# %%
## Your codes begin here:
fig = plt.figure(figsize=(8,6))
aux1 = fig.add_subplot(2,2,1)
aux2 = fig.add_subplot(2,2,2)
aux3 = fig.add_subplot(2,2,3)
aux4 = fig.add_subplot(2,2,4)
aux1.plot(array1, color='r', marker='o')
aux2.plot(array2, color='y', marker='o')
aux3.plot(array3, color='b', marker='o')
aux4.plot(array4, color='g', marker='o')

# %% [markdown]
# #### Q3. In this task, you are required to do the following:
#
# #### 1. Create a line plot for 'array1' with red color and rectangle marker.
# #### 2. Create a line plot for 'array2' on the same subplot as array1, with green color and rectangle marker.
# #### 3. Add x-axis and y-axis labels ('X-Values' and 'Y-Values', respectively).
# #### 4. Add a title for this figure ('My Figure Title').
# #### 5. Add a legend for this figure.
#
# Hint1: Create a figure with only one subplot using function the **plt.subplots(1,1).
#
# Hint2: To add labels and a title, use the functions **set_xlabel()**, **set_ylabel()** and **set_title()**.
#
# Hint3: To add a legend, use the function **legend()** and the argument **label** for the plot function.
#
# Hint4: Refer to the lectures four and five of module 13 for more information.

# %%
## Your codes begin here:
fig = plt.figure(figsize=(8,6))
aux1 = fig.add_subplot()
aux1.plot(array1, color='r', marker='v')
aux1.plot(array2, color='g', marker='s')
aux1.set_xlabel('X-label')
aux1.set_ylabel('Y-label')
aux1.set_title('My Figure')
aux1.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### Q4. Use the dataframe which is created for you in the code cell below to do the following:
#
# #### 1. Use pandas library to create a bar plot for this dataframe ('frame1')?
#    **Hint:** use the function **plot.bar()
#
# #### 2. Use pandas library to create a separate line plot for each column in this dataframe ('frame1')?
#    **Hint:** use the function **plot()**, to create separate plots use the argument **subplots = True**
#
# #### 3. Use seaborn library to create a bar plot for the column 'sale1' in this dataframe 'frame1'?
#    **Hint:** use the function **sns.barplot()

# %%
# Just run this cell to create the dataframe:

frame1 = pd.read_csv('data/ex7.csv', index_col = 'year')
frame1
# Out:
#       sale1  sale2  sale3
# year
# 2019    200    258    592
# 2020    328    664    606
# 2021    870    249    918
# 2022    209    971    629

# %%
# 1. Use pandas library to create a bar plot for this dataframe ('frame1')?
## Your codes begin here:
frame1.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#2. Use pandas library to create a separate line plot for each column in this dataframe ('frame1')?
## Your codes begin here:
frame1.plot.line(subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
#1. 3. Use seaborn library to create a bar plot for the column 'sale1' in this dataframe 'frame1'?
## Your codes begin here:
#sns.barplot(x=frame1.index, y=frame1['sale1'])
sns.catplot(x=frame1.index, y=frame1['sale1'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 4>()
#       1 #1. 3. Use seaborn library to create a bar plot for the column 'sale1' in this dataframe 'frame1'?
#       2 ## Your codes begin here:
#       3 #sns.barplot(x=frame1.index, y=frame1['sale1'])
# ----> 4 sns.catplot(x=frame1.index, y=frame1['sale1'])
#
# File ~\miniconda3\envs\dataScience\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\miniconda3\envs\dataScience\lib\site-packages\seaborn\categorical.py:3844, in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3839     plot_kws.update(
#    3840         estimator=estimator, ci=ci, n_boot=n_boot, units=units, seed=seed,
#    3841     )
#    3843 # Initialize the facets
# -> 3844 g = FacetGrid(**facet_kws)
#    3846 # Draw the plot onto the facets
#    3847 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#
# File ~\miniconda3\envs\dataScience\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\miniconda3\envs\dataScience\lib\site-packages\seaborn\axisgrid.py:364, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     360 hue_kws = hue_kws if hue_kws is not None else {}
#     362 # Make a boolean mask that is True anywhere there is an NA
#     363 # value in one of the faceting variables, but only if dropna is True
# --> 364 none_na = np.zeros(len(data), bool)
#     365 if dropna:
#     366     row_na = none_na if row is None else data[row].isnull()
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ***
# # Solutions
# ***

# %% [markdown]
# #### Q1. Create line plots for the four arrays (which are created in the first code cell below) in four separate subplots?

# %%
## just run this cell to create the four arrays

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(50)   ## Used to generate the same numbers each time we run the script.


array1 = np.random.randn(10).cumsum()
array2 = np.random.randn(10).cumsum()
array3 = np.random.randn(10).cumsum()
array4 = np.random.randn(10).cumsum()

# %%
## Your codes begin here:

fig, ax = plt.subplots(2, 2)
ax[0,0].plot(array1)
ax[0,1].plot(array2)
ax[1,0].plot(array3)
ax[1,1].plot(array4)

# %% [markdown]
# #### Q2. Modify your answer code in Q1, to change the color of the plots into (green, blue, red and black), respectively? And to add circle-markers to all plots?

# %%
## Your codes begin here:

fig, ax = plt.subplots(2, 2)
ax[0,0].plot(array1, color = 'green', marker = 'o')
ax[0,1].plot(array2, color = 'blue', marker = 'o')
ax[1,0].plot(array3, color = 'red', marker = 'o')
ax[1,1].plot(array4, color = 'black', marker = 'o')

# %% [markdown]
# #### Q3. In this task, you are required to do the following:
#
# #### 1. Create a line plot for 'array1' with red color and rectangle marker.
# #### 2. Create a line plot for 'array2' on the same subplot as array1, with green color and rectangle marker.
# #### 3. Add x-axis and y-axis labels ('X-Values' and 'Y-Values', respectively).
# #### 4. Add a title for this figure ('My Figure Title').
# #### 5. Add a legend for this figure.

# %%
## Your codes begin here:

fig, ax = plt.subplots(1,1)
ax.plot(array1, color = 'red', marker = 's', label = 'array1')
ax.plot(array2, color = 'green', marker = 's', label = 'array2')
ax.set_xlabel('X-Values')
ax.set_ylabel('Y-Values')
ax.set_title('My Figure Title')
ax.legend()

# %% [markdown]
# #### Q4. Use the dataframe which is created for you in the code cell below to do the following:
#
# #### 1. Use pandas library to create a bar plot for this dataframe ('frame1')?
#
# #### 2. Use pandas library to create a separate line plot for each column in this dataframe ('frame1')?
#
# #### 3. Use seaborn library to create a bar plot for the column 'sale1' in this dataframe 'frame1'?

# %%
# Just run this cell to create the dataframe:

frame1 = pd.read_csv('data/ex7.csv', index_col = 'year')
frame1
# Out:
#       sale1  sale2  sale3
# year
# 2019    200    258    592
# 2020    328    664    606
# 2021    870    249    918
# 2022    209    971    629

# %%
# 1. Use pandas library to create a bar plot for this dataframe ('frame1')?
## Your codes begin here:

frame1.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#2. Use pandas library to create a separate line plot for each column in this dataframe ('frame1')?
## Your codes begin here:

frame1.plot(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
#1. 3. Use seaborn library to create a bar plot for the column 'sale1' in this dataframe 'frame1'?
## Your codes begin here:

sns.barplot( x= frame1.index, y = frame1['sale1'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='sale1'>

# %% [markdown]
# ***
#
# <h1 align="center">Thank You</h1>
#
# ***
