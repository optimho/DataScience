# %%
import pandas as pd

# %%
apple =pd.read_csv("data/apple.csv", index_col='Date', parse_dates=True)

# %%
apple.head()
# Out:
#             Close
# Date
# 2021-01-04  129.4
# 2021-01-05  131.0
# 2021-01-06  126.6
# 2021-01-07  130.9
# 2021-01-08  132.1

# %%
apple['Close'].plot()
apple['Close'].rolling(window=30).mean().plot()
apple['Close'].rolling(window=60).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
air = pd.read_csv('data/AirPassenger.csv', index_col='Month', parse_dates=True)

# %%
air.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
air['Passengers'].plot(figsize=(8,5))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
air['Passengers'].plot(figsize=(8,5))
air['Passengers'].rolling(window=10).mean().plot()
# Out:
# <AxesSubplot:xlabel='Month'>
