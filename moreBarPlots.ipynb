# %%
import pandas as pd

# %%
dataFrame1 = pd.read_csv("data/ex6.csv")
dataFrame1
# Out:
#   branch number  sale1  sale2  sale3
# 0       branch1    200    258    592
# 1       branch2    328    664    606
# 2       branch3    870    249    918
# 3       branch4    209    971    629

# %%
dataFrame1.set_index("branch number", inplace=True)

# %%
dataFrame1.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='branch number'>

# %%
dataFrame1.plot.bar(stacked=True, rot=0)
# Out:
# <AxesSubplot:xlabel='branch number'>

# %%
dataFrame1.plot.barh(stacked=True, rot=0)
# Out:
# <AxesSubplot:ylabel='branch number'>

# %%
dataFrame1.plot(kind='bar', stacked=True, rot=0)
# Out:
# <AxesSubplot:xlabel='branch number'>
