# %%
import pandas as pd
import seaborn as sns

# %%
frame = pd.read_csv("data/ex13.csv")
frame.head()
# Out:
#     age  wage
# 0  39.0  48.0
# 1  28.0  44.0
# 2  28.0  49.0
# 3  36.0  56.0
# 4  30.0  24.0

# %%
frame.count()
# Out:
# age     500
# wage    500
# dtype: int64

# %%
frame['age'].plot.hist(bins=22)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
frame['wage'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
frame.age.plot.hist(bins=20, color='red',edgecolor='black', linewidth = 1)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
frame['wage'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(frame['wage'], bins=20, color='r')

# %%
sns.displot(frame['wage'],kind='kde', color='b')

# %%
fig = sns.displot(frame['wage'],kind='kde', color='b')
fig.savefig('figures/name.jpg')
